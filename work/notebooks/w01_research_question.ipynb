# %% [markdown]
# <a href="https://colab.research.google.com/github/AlishaUsman/FlyRank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AlishaUsman/FlyRank_ML_Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# ## **My Lane**
#
# *I chose the Content Refresh Prioritization lane because it focuses on identifying pages that should be reviewed and updated first. This can help prioritize work more effectively instead of reviewing every page manually. Based on the starter dataset and the initial notebooks, this appears to be a practical machine learning problem with measurable outcomes.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# ## **Research Question**
#
# **Decision:**
# *Which content pages should be prioritized for refresh?*
#
# **Action:**
# *The SEO or content team can update the highest-priority pages first.*
#
# **Cost of a wrong recommendation:**
# *If the wrong pages are selected, valuable pages may continue losing traffic while time is wasted updating less important pages.*
#
# **Why ML helps:**
# *Machine learning can analyze multiple signals together and rank pages more effectively than relying only on manual rules.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, subprocess

if not os.path.exists("data/raw/content_refresh_anonymized.csv"):
    # !git clone --depth 1 https://github.com/flyrank-bih/flyrank-ml-internship-starter
    os.chdir("flyrank-ml-internship-starter")

print("Working Directory:", os.getcwd())
# Out:
# Cloning into 'flyrank-ml-internship-starter'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 91 (delta 12), reused 56 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (91/91), 1.81 MiB | 11.90 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# Working Directory: /content/flyrank-ml-internship-starter

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Declining pages:", (df["trend_direction"] == "down").sum())
print("Average CTR:", round(df["ctr"].mean(), 4))
# Out:
# Total pages: 30000
# Declining pages: 16262
# Average CTR: 0.5107

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# *My project can identify patterns and provide decision support for prioritizing content refresh. The results are based on observed data and measured relationships. It cannot prove why pages decline, predict Google's algorithm, or guarantee future rankings. Any recommendations should be used as guidance rather than certainty.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
